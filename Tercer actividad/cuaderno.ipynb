# %% [markdown]
# ## 1. Carga y exploración de datos

# %%
# Importa las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.model_selection import train_test_split

# Carga el fichero empleados.csv
df_empleados = pd.read_csv("empleados.csv", sep=",")

# Muestra las primeras filas del conjunto de datos
print(df_empleados.head())

# Comprueba si hay nulos o inconsistencias (si salen false, es que el valor no es nulo)
print(df_empleados.isnull())
# Out:
#    edad  experiencia  formacion  horas_extra  salario
# 0    23            1          1            5     1250
# 1    25            2          1            8     1320
# 2    28            4          2            6     1650
# 3    30            6          2           10     1850
# 4    32            8          2           12     2050
#      edad  experiencia  formacion  horas_extra  salario
# 0   False        False      False        False    False
# 1   False        False      False        False    False
# 2   False        False      False        False    False
# 3   False        False      False        False    False
# 4   False        False      False        False    False
# 5   False        False      False        False    False
# 6   False        False      False        False    False
# 7   False        False      False        False    False
# 8   False        False      False        False    False
# 9   False        False      False        False    False
# 10  False        False      False        False    False
# 11  False        False      False        False    False
# 12  False        False      False        False    False
# 13  False        False      False        False    False
# 14  False        False      False        False    False
# 15  False        False      False        False    False
# 16  False        False      False        False    False
# 17  False        False      False        False    False
# 18  False        False      False        False    False
# 19  False        False      False        False    False

# %% [markdown]
# ## 2. Análisis exploratorio

# %%
# Calcula estadisticas descriptivas básicas
print(df_empleados.describe())

# Representa gráficamente la relacion entre variables independientes y el salario
relaciones = df_empleados.corr(numeric_only=True)["salario"].sort_values()
plt.plot(relaciones)
plt.title("Gráfica entre variables independientes y el salario")
# Out:
#            edad  experiencia  formacion  horas_extra      salario
# count  20.00000    20.000000  20.000000    20.000000    20.000000
# mean   33.25000     9.000000   2.250000     8.100000  2116.500000
# std     6.76582     6.112972   0.786398     3.582119   601.631772
# min    23.00000     1.000000   1.000000     2.000000  1200.000000
# 25%    27.75000     3.750000   2.000000     5.750000  1632.500000
# 50%    33.00000     8.500000   2.000000     8.000000  2100.000000
# 75%    38.25000    13.250000   3.000000    10.250000  2620.000000
# max    45.00000    20.000000   3.000000    15.000000  3000.000000
# Text(0.5, 1.0, 'Gráfica entre variables independientes y el salario')

# %% [markdown]
# ## 3. Preparación de los datos

# %%
# Separa las variables independientes (X), de las variables dependientes (Y)
x = df_empleados.drop(columns=["salario"])
y = df_empleados["salario"]

# Divide el conjunto de datos en conjunto de entrenamiento y prueba (por ejemplo, 80%, 20%)
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=.8, random_state=25)

# Justifica brevemente porque es necesaria esta división

# %% [markdown]
# ## 4. Construcción del modelo

# %%
# Crea un modelo de regresión lineal


# Entrena el modelo con los datos de entrenamiento (arriba)


# Muestra la ecuación del modelo obtenido
