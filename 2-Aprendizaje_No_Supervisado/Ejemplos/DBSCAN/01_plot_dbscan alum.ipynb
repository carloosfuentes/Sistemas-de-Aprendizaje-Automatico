# %% [markdown]
# # Demo of DBSCAN clustering algorithm
#
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) finds core
# samples in regions of high density and expands clusters from them. This
# algorithm is good for data which contains clusters of similar density.
#
# See the `sphx_glr_auto_examples_cluster_plot_cluster_comparison.py` example
# for a demo of different clustering algorithms on 2D datasets.

# %%
# Authors: The scikit-learn developers
# SPDX-License-Identifier: BSD-3-Clause
# ESte ejemplo está tomado de la documentación oficial de sklearn (https://scikit-learn.org/stable/auto_examples/cluster/plot_dbscan.html)

# %% [markdown]
# ## Data generation
#
# We use :class:`~sklearn.datasets.make_blobs` to create 3 synthetic clusters.

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(
    n_samples=750, centers=centers, cluster_std=0.4, random_state=0
)

X = StandardScaler().fit_transform(X)

# %% [markdown]
# We can visualize the resulting data:

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %% [markdown]
# ## Compute DBSCAN
#
# One can access the labels assigned by :class:`~sklearn.cluster.DBSCAN` using
# the `labels_` attribute. Noisy samples are given the label $-1$.

# %%
import numpy as np

from sklearn import metrics
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=0.3, min_samples=10).fit(X)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 18

# %% [markdown]
# Clustering algorithms are fundamentally unsupervised learning methods.
# However, since :class:`~sklearn.datasets.make_blobs` gives access to the true
# labels of the synthetic clusters, it is possible to use evaluation metrics
# that leverage this "supervised" ground truth information to quantify the
# quality of the resulting clusters. Examples of such metrics are the
# homogeneity, completeness, V-measure, Rand-Index, Adjusted Rand-Index and
# Adjusted Mutual Information (AMI).
#
# If the ground truth labels are not known, evaluation can only be performed
# using the model results itself. In that case, the Silhouette Coefficient comes
# in handy.
#
# For more information, see the
# `sphx_glr_auto_examples_cluster_plot_adjusted_for_chance_measures.py`
# example or the `clustering_evaluation` module.

# %%
print(f"Homogeneity: {metrics.homogeneity_score(labels_true, labels):.3f}")
print(f"Completeness: {metrics.completeness_score(labels_true, labels):.3f}")
print(f"V-measure: {metrics.v_measure_score(labels_true, labels):.3f}")
print(f"Adjusted Rand Index: {metrics.adjusted_rand_score(labels_true, labels):.3f}")
print(
    "Adjusted Mutual Information:"
    f" {metrics.adjusted_mutual_info_score(labels_true, labels):.3f}"
)
print(f"Silhouette Coefficient: {metrics.silhouette_score(X, labels):.3f}")
# Out:
# Homogeneity: 0.953
# Completeness: 0.883
# V-measure: 0.917
# Adjusted Rand Index: 0.952
# Adjusted Mutual Information: 0.916
# Silhouette Coefficient: 0.626

# %% [markdown]
# ## Plot results
#
# Core samples (large dots) and non-core samples (small dots) are color-coded
# according to the assigned cluster. Samples tagged as noise are represented in
# black.

# %%
unique_labels = set(labels)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=14,
    )

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

plt.title(f"Estimated number of clusters: {n_clusters_}")
plt.show()

# %% [markdown]
# ## VAmos a ver ahora el resultado de aplicar K-Means

# %%
from sklearn.cluster import KMeans

# Definimos K-Means. Usamos 3 porque sabemos que el notebook generó 3 centros.
kmeans = KMeans(n_clusters=3, random_state=42, n_init='auto')
kmeans_labels = kmeans.fit_predict(X)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# K-Means
ax[0].scatter(X[:, 0], X[:, 1], c=kmeans_labels, cmap="viridis", s=35, alpha=0.7)
ax[0].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
              marker="X", c="red", s=200, edgecolors="k", label="Centroides")
ax[0].set_title("K-Means (k=3)")

# DBSCAN: Simplificado con scatter usando la máscara de ruido directamente
# Los puntos con label -1 se pintarán según el colormap, o puedes usar un array de colores.
ax[1].scatter(X[:, 0], X[:, 1], c=labels, cmap="plasma", s=35, edgecolors='k', alpha=0.7)
ax[1].set_title(f"DBSCAN (Clusters: {n_clusters_})")

for a in ax:
    a.set_xlabel("C1"); a.set_ylabel("C2")
    if a == ax[0]: a.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pruebas
# ### 1. Sensibilidad del Hiperparámetro Epsilon ($\epsilon$)
# **Instrucción:** Regresa a la celda de configuración de DBSCAN.
# * Cambia `eps` a **0.1** y observa el gráfico.
#     - Si cambio epsilon a 0.1 se formarán muchos mas grupos (12 grupos en total) los cuales no tienen sentido, es decir, no tiene sentido dividir los datos en todos esos grupos. En definitiva, en base a la representación gráfica el parámetro mas correcto es 0.3
# * Luego cámbialo a **1.0** y observa el resultado.
#     - Si ponemos epsilon = 1, el resultado saldrá que solo hay 1 grupo porque hemos puesto una distancia tan grande que no hay ningun punto que esté mas alejado, haciendo que todos los puntos se fusionen dentro de un grupo. Este valor como es lógico, es incorrecto
# * **Pregunta:** ¿Cómo afecta el valor de Epsilon a la cantidad de puntos considerados como "ruido"? Justifica tu respuesta.
#     - El valor de épsilon tiene mucho que ver con los valores de ruido, ya que este parámetro controla la distancia entre los puntos para distinguirlos entre diferentes grupos. En el caso de que este sea pequeño habra muchos vecinos con lo cual pueden aparecer muchos grupos, y si épsilon es muy grande, se disminuye el grupo pero puede que todos los puntos estén dentro del mismo grupo
# ### 2. Gestión de Outliers (DBSCAN vs. K-Means)
# **Instrucción:** Observa los puntos negros en el gráfico de DBSCAN y compáralos con el mismo sector en el gráfico de K-Means.
# * **Pregunta:** ¿Qué ventaja presenta DBSCAN en un entorno de datos con anomalías (como detección de fraude) frente a K-Means?
#     - La ventaja de DBSCAN es que es capaz de identificar los outliers como ruido, en vez de obligarlos a pertener a un grupo, es decir, los excluye. Esto no pasa en K-Means ya que si o si los incluye dentro de un grupo
