# %% [markdown]
# # Descenso del gradiente en 3D
#
# Este notebook muestra un ejemplo sencillo de descenso del gradiente en una función de dos variables:
#
# $$f(x,y)=x^2+y^2$$
#
# La idea es visualizar cómo el algoritmo desciende por una superficie hasta acercarse al mínimo.

# %% [markdown]
# ## 1. Importar librerías

# %%
# Importando librerias
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## 2. Definición de la función y de su gradiente
#
# Trabajamos con la función:
#
# $$f(x,y)=x^2+y^2$$
#
# Su gradiente es:
#
# $$\nabla f(x,y)=(2x,2y)$$
#
# >Como hemos visto, el gradiente es la derivada (en este caso nos la dan ya calculada)

# %%
# Definiendo la funcion y el gradiente
def f(x, y):
    return x**2 + y**2

def grad(x, y):
    return 2*x, 2*y

# %% [markdown]
# ## 3. Aplicación del Descenso del Gradiente
#
# Partimos de un punto inicial y actualizamos los parámetros con la regla:
# <!-- A continuación aparecen las expresiones. los símbolos son la forma en que Markdown nos permite manejar expresiones matemáticas -->
# $$x_{nuevo}=x-\alpha \frac{\partial f}{\partial x}$$
# $$y_{nuevo}=y-\alpha \frac{\partial f}{\partial y}$$

# %%
# Parámetros iniciales
alpha = 0.1
x, y = 3.5, 3.0
iteraciones = 15

# Guardar trayectoria
xs = [x]
ys = [y]
zs = [f(x, y)]

# Descenso del gradiente
for i in range(iteraciones):
    gx, gy = grad(x, y)
    x = x - alpha * gx
    y = y - alpha * gy
    xs.append(x)
    ys.append(y)
    zs.append(f(x, y))

for i in range(len(xs)):
    print(f"Iteración {i}: x = {xs[i]:.4f}, y = {ys[i]:.4f}, f(x,y) = {zs[i]:.4f}")
# Out:
# Iteración 0: x = 3.5000, y = 3.0000, f(x,y) = 21.2500
# Iteración 1: x = 2.8000, y = 2.4000, f(x,y) = 13.6000
# Iteración 2: x = 2.2400, y = 1.9200, f(x,y) = 8.7040
# Iteración 3: x = 1.7920, y = 1.5360, f(x,y) = 5.5706
# Iteración 4: x = 1.4336, y = 1.2288, f(x,y) = 3.5652
# Iteración 5: x = 1.1469, y = 0.9830, f(x,y) = 2.2817
# Iteración 6: x = 0.9175, y = 0.7864, f(x,y) = 1.4603
# Iteración 7: x = 0.7340, y = 0.6291, f(x,y) = 0.9346
# Iteración 8: x = 0.5872, y = 0.5033, f(x,y) = 0.5981
# Iteración 9: x = 0.4698, y = 0.4027, f(x,y) = 0.3828
# Iteración 10: x = 0.3758, y = 0.3221, f(x,y) = 0.2450
# Iteración 11: x = 0.3006, y = 0.2577, f(x,y) = 0.1568
# Iteración 12: x = 0.2405, y = 0.2062, f(x,y) = 0.1004
# Iteración 13: x = 0.1924, y = 0.1649, f(x,y) = 0.0642
# Iteración 14: x = 0.1539, y = 0.1319, f(x,y) = 0.0411
# Iteración 15: x = 0.1231, y = 0.1056, f(x,y) = 0.0263

# %% [markdown]
# ## 4. Representación de la superficie y de la trayectoria

# %%
# Malla para dibujar la superficie
x_vals = np.linspace(-4, 4, 100)
y_vals = np.linspace(-4, 4, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

# Gráfica 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, alpha=0.6)
ax.plot(xs, ys, zs, marker='o')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x,y)')
ax.set_title('Descenso del gradiente en 3D')

plt.show()

# %%
# Representación en 2D
plt.contour(X, Y, Z, levels=30)
plt.plot(xs, ys, 'ro-')
plt.title("Trayectoria del descenso de gradiente")
plt.show()

# %% [markdown]
# ## 5. Preguntas
#
# Responde justificadamente las siguientes cuestiones.
# 1. ¿Hacia qué punto se aproxima la trayectoria del algoritmo?
#     - La trayectoria converge hacia (0, 0), porque en esa función ese punto es el mínimo global y el gradiente vale cero. Eso significa que ya no hay dirección de descenso y el algoritmo se estabiliza allí.
# 2. ¿Qué representa la altura en el eje $z$?
#     - La altura en el eje z representa el valor de la función "f(x)". Es decir, cuanto más alto está el punto, mayor es el valor de la función y cuanto más bajo, más cerca estamos del mínimo.
# 3. ¿Qué crees que ocurriría si aumentamos mucho el valor de `alpha`?
#     - Si aumentamos mucho el valor de alpha, este va a oscilar demasiado, porque es como si diese pasos demasiado grandes dando lugar a que no se ajuste bien a la función, por eso hay que usar valores mas pequeños de alfa, para que haga un descenso controlado. Para comprobarlo, he modificado el parámetro para observarlo correctamente.
#
#     - Con `alpha = 0.9`:
#
#         ![Alpha 0.9](attachment:image.png)
#
#     - Con `alpha = 0.1`:
#
#         ![Alpha 0.1](attachment:image-2.png)

# %% [markdown]
# # 6. Ejemplos

# %% [markdown]
# ## 6.1 Tipo Silla

# %%
# Importando librerias
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Crear malla
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Superficie tipo "silla"
Z = X**2 - Y**2

# Representación 3D
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, alpha=0.8)

ax.set_title("Superficie tipo saddle: f(x,y) = x² - y²")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")

plt.show()

# %% [markdown]
# ## 6.1.1 Trayectoria

# %%
# Representación en 2D
plt.contour(X, Y, Z, levels=30)
plt.plot(xs, ys, 'ro-')
plt.title("Trayectoria del descenso de gradiente de la silla")
plt.show()

# %% [markdown]
# ## 6.2. Paraboloide

# %%
#paraboloide
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Crear malla
x = np.linspace(-4, 4, 100)
y = np.linspace(-4, 4, 100)
X, Y = np.meshgrid(x, y)

# Paraboloide
Z = X**2 + Y**2

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, alpha=0.8)

ax.set_title("Superficie paraboloide: f(x,y) = x² + y²")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")

plt.show()

# %% [markdown]
# ## 6.2.1 Trayectoria

# %%
# Representación en 2D
plt.contour(X, Y, Z, levels=30)
plt.plot(xs, ys, 'ro-')
plt.title("Trayectoria del descenso de gradiente del paraboloide")
plt.show()

# %% [markdown]
# ## 6.3. Función de Rosenbrock

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Crear malla
x = np.linspace(-2, 2, 200)
y = np.linspace(-1, 3, 200)
X, Y = np.meshgrid(x, y)

# Función de Rosenbrock
Z = (1 - X)**2 + 100*(Y - X**2)**2

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap="viridis")

ax.set_title("Función de Rosenbrock")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")

plt.show()

# %% [markdown]
# ## 6.3.1 Trayectoria

# %%
# Representación en 2D
plt.contour(X, Y, Z, levels=100)
plt.plot(xs, ys, 'ro-')
plt.title("Trayectoria del descenso de gradiente en superficie Rosenbrock")
plt.show()

# %% [markdown]
# ## 7. Cuestiones
# Contesta con tus palabras las siguientes cuestiones sobre los tres casos resueltos (celdas 5, 6.1. y 6.2.):
# 1. ¿En cuál crees que el descenso de gradiente converge más fácilmente?
#     - El descenso de gradiente converge más fácil en el paraboloide porque la superficie es suave, convexa y tiene un mínimo global claro. Como se ha visto en el punto 5 cambiando de alfa.
# 2. ¿En cuál puede tener más dificultad?
#     - En el que más dificultad hay es en la función de Rosenbrock. Aunque tiene un mínimo global, su valle es estrecho y curvado, así que avanzar de forma estable cuesta más.
# 3. ¿Por qué la función de Rosenbrock se utiliza para probar algoritmos de optimización?
#     - La función de Rosenbrock se utiliza para evaluar algoritmos de optimización porque tiene un mínimo global y presenta un valle muy estrecho y curvado que dificulta la convergencia. Por eso sirve para detectar si un método es robusto o si se atasca y avanza lentamente.
# 4. ¿Por qué el descenso de gradiente sigue siempre la dirección del gradiente negativo?
#     - Porque el gradiente señala la dirección de máximo crecimiento de la función. Por tanto, si queremos minimizarla, debemos movernos en la dirección opuesta, que es la que produce la mayor disminución local del valor de la función.
# 5. ¿En cuál de las tres superficies el descenso de gradiente debería converger más rápidamente?
#     - De las tres superficies, debería converger más rápido en el paraboloide, porque su forma hace que el camino hacia el mínimo sea directo y estable.
# 6. ¿En cuál podría tardar más o presentar oscilaciones?
#     - Puede tardar más o presentar oscilaciones en Rosenbrock, porque el valle obliga a corregir continuamente la dirección.
# 7. ¿Por qué crees que en problemas reales de Machine Learning la superficie de error puede ser mucho más compleja?
#     - Porque intervienen muchos parámetros a la vez. Eso genera valles, zonas planas, curvaturas distintas y regiones donde optimizar resulta bastante más difícil.
# 8. Indica algún caso de Machine Learning en el que aparezcan los tres tipos de superficies estudiados en este Notebook.
#     - Un claro ejemplo es el entrenamiento de una red neuronal. Según la zona del espacio de parámetros, puede aparecer un comportamiento parecido a un paraboloide cerca de un mínimo, a una silla en puntos críticos, y a Rosenbrock en regiones estrechas y mal condicionadas.

# %% [markdown]
# ## 8. Opcional
# Utilizando la Celda 5, para la superficie del paraboloide crea una nueva celda en la que podamos comparar tres trayectorias distintas con tres alphas distintos (uno muy pequeño, uno óptimo y uno que provoque divernecia).
#
# - Con un alpha demasiado grande, el algoritmo da pasos excesivos, se pasa del mínimo en cada iteración y acaba oscilando o divergiendo en lugar de converger.

# %%
# Función para calcular la trayectoria del descenso de gradiente en el paraboloide
def trayectoria_paraboloide(alpha, x0=3.0, y0=2.0, iteraciones=12):
    x, y = x0, y0
    xs = [x]
    ys = [y]
    for i in range(iteraciones):
        gx, gy = 2*x, 2*y
        x = x - alpha * gx
        y = y - alpha * gy
        xs.append(x)
        ys.append(y)
    return xs, ys

# Malla para dibujar la superficie
x_vals = np.linspace(-4, 4, 200)
y_vals = np.linspace(-4, 4, 200)
X, Y = np.meshgrid(x_vals, y_vals)
Z = X**2 + Y**2

# Lista de alphas para comparar
alphas = [(0.02, 'Muy pequeño'), (0.5, 'Óptimo'), (1.1, 'Divergente')]

# Mostrar las trayectorias para diferentes alphas
plt.figure(figsize=(8, 6))
plt.contour(X, Y, Z, levels=30, cmap='viridis')

# Bucle para recorrer cada alpha y calcular su trayectoria
for alpha, etiqueta in alphas:
    xs, ys = trayectoria_paraboloide(alpha)
    plt.plot(xs, ys, 'o-', label=f'alpha = {alpha} ({etiqueta})')

plt.title('Comparación de trayectorias con distintos alpha')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
